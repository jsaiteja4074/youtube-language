# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import time
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.preprocessing import LabelEncoder
#from keras.utils import np_utils
from sklearn.ensemble import RandomForestClassifier
from nltk.stem import PorterStemmer
import nltk

# %% [markdown]
# ### Reading YouTube Data

# %%
data= pd.read_csv("YoutubeDataSet.csv", header=0)

data.head()
# Out:
#                                                Title              Videourl  \
# 0  Madagascar Street Food!!! Super RARE Malagasy ...  /watch?v=EwBA1fOQ96c
# 1            42 Foods You Need To Eat Before You Die  /watch?v=0SPwwpruGIA
# 2                Gordon Ramsay’s Top 5 Indian Dishes  /watch?v=upfu5nQB2ks
# 3        How To Use Chopsticks - In About A Minute 🍜  /watch?v=xFRzzSF_6gk
# 4                       Trying Indian Food 1st Time!  /watch?v=K79bXtaRwcM
#
#   Category                                        Description
# 0     Food  🎥GIANT ALIEN SNAIL IN JAPAN! » https://youtu.b...
# 1     Food  This is the ultimate must-try food bucket list...
# 2     Food  We found 5 of the best and most interesting In...
# 3     Food  You're most likely sitting in a restaurant wit...
# 4     Food  HELP SUPPORT SINSTV!! Shop Our Sponsors!\nLast...

# %%
print(data.shape)
print(data.isnull().values.any())
# Out:
# (11211, 4)
# True

# %%
data=data.dropna()
print(data.isnull().values.any())
# Out:
# False

# %%
Category=data['Category'].value_counts()
print(Category.shape)
print(Category)
# Out:
# (6,)
# Category
# travel blog           2200
# Science&Technology    2074
# Food                  1828
# manufacturing         1699
# Art&Music             1682
# History               1645
# Name: count, dtype: int64

# %% [markdown]
# ### Preprocessing of Description

# %%
import nltk
import re
from nltk.corpus import stopwords

# Download the 'stopwords' corpus
nltk.download('stopwords')

# loading stop words from nltk library
stop_words = set(stopwords.words('english'))

#Stemmering the word
sno = nltk.stem.SnowballStemmer('english') #initialising the snowball stemmer

def preprocessing(total_text, index, column):
    if type(total_text) is not int:
        string = ""
        #Removing link
        url_pattern = r'((http|ftp|https):\/\/)?[\w\-_]+(\.[\w\-_]+)+([\w\-\.,@?^=%&amp;:/~\+#]*[\w\-\@?^=%&amp;/~\+#])?'
        total_text = re.sub(url_pattern, ' ', total_text)
        #removing email address
        email_pattern =r'[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.[a-z]+'
        total_text = re.sub(email_pattern, ' ', total_text)
        # replace every special char with space
        total_text = re.sub('[^a-zA-Z0-9\n]', ' ', total_text)
        # replace multiple spaces with single space
        total_text = re.sub('\s+',' ', total_text)
        # converting all the chars into lower-case.
        total_text = total_text.lower()

        for word in total_text.split():
        # if the word is a not a stop word then retain that word from the data
            if not word in stop_words:
                word=(sno.stem(word))
                string += word + " "

        data[column][index] = string
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\j sai
# [nltk_data]     teja\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#text processing stage.
start_time = time.process_time()
for index, row in data.iterrows():
    if type(row['Description']) is str:
        preprocessing(row['Description'], index, 'Description')
print('Time took for preprocessing the text :',time.process_time() - start_time, "seconds")
# Out:
# Time took for preprocessing the text : 3.703125 seconds

# %%
data.head(10)
# Out:
#                                                Title              Videourl  \
# 0  Madagascar Street Food!!! Super RARE Malagasy ...  /watch?v=EwBA1fOQ96c
# 1            42 Foods You Need To Eat Before You Die  /watch?v=0SPwwpruGIA
# 2                Gordon Ramsay’s Top 5 Indian Dishes  /watch?v=upfu5nQB2ks
# 3        How To Use Chopsticks - In About A Minute 🍜  /watch?v=xFRzzSF_6gk
# 4                       Trying Indian Food 1st Time!  /watch?v=K79bXtaRwcM
# 5  Blippi Tours the Chocolate Factory | Learn abo...  /watch?v=uSIb-Wbyx6Y
# 6  EGYPT: Vegetarian food | Mobile Sim | Indian S...  /watch?v=Gozaqmg6hmk
# 7     Chinese Street Food Liuhe Tourist Night Market  /watch?v=H0xKYgUX3zI
# 8  India's Biggest food FESTIVAL | food truck fes...  /watch?v=NpOVNb1keoc
# 9  Street Food in Madagascar's Biggest City!!! Ze...  /watch?v=OXHHNBVt0pw
#
#   Category                                        Description
# 0     Food  giant alien snail japan go tour madagascar get...
# 1     Food  ultim must tri food bucket list burger dip che...
# 2     Food  found 5 best interest indian recip channel inc...
# 3     Food  like sit restaur set chopstick hand say video ...
# 4     Food  help support sinstv shop sponsor last longer b...
# 5     Food  blippi eat veget blippi take tour chocol facto...
# 6     Food  video see hunt best mobil network egypt base f...
# 7     Food  tri mani differ kind chines street food liuh t...
# 8     Food  alright guy hope like video aim find somewhat ...
# 9     Food  villag food madagascar go tour madagascar get ...

# %% [markdown]
# ### Splitting data into train, test,cv

# %%
y_true = data['Category'].values
# split the data into test and train by maintaining same distribution of output varaible 'y_true' [stratify=y_true]
X_train, test_df, y_train, y_test = train_test_split(data, y_true, stratify=y_true, test_size=0.2)
train_df, cv_df, y_train, y_cv = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2)

# %%
print('Number of data points in train data:', train_df.shape[0])
print('Number of data points in test data:', test_df.shape[0])
print('Number of data points in cv data:', cv_df.shape[0])
# Out:
# Number of data points in train data: 7121
# Number of data points in test data: 2226
# Number of data points in cv data: 1781

# %% [markdown]
# ### Distribution of y_i's in Test

# %%
test_dfCategory=test_df['Category'].value_counts()
print(test_dfCategory)
print('Distribution of y in test')
plt.figure(figsize=(8,8))
sns.barplot(x=test_dfCategory.index, y=test_dfCategory.values, alpha=0.8) # Pass x and y as keyword arguments
plt.title('Distribution of y in test')
plt.ylabel('data point per class')
plt.xlabel('Class')
plt.xticks(rotation=90)
plt.show()
# Out:
# Category
# travel blog           440
# Science&Technology    415
# Food                  366
# manufacturing         340
# Art&Music             336
# History               329
# Name: count, dtype: int64
# Distribution of y in test

# %% [markdown]
# ### Distribution of y_i's in CV

# %%
cv_dfCategory=cv_df['Category'].value_counts()
print(cv_dfCategory)
print('Distribution of y in cv')
plt.figure(figsize=(8,8))
sns.barplot(x=cv_dfCategory.index,y=cv_dfCategory.values, alpha=0.8)
plt.title('Distribution of y in cv')
plt.ylabel('data point per class')
plt.xlabel('Class')
plt.xticks(rotation=90)
plt.show()
# Out:
# Category
# travel blog           352
# Science&Technology    332
# Food                  293
# manufacturing         272
# Art&Music             269
# History               263
# Name: count, dtype: int64
# Distribution of y in cv

# %% [markdown]
# ## Text vectorization[BOW,TF-IDF]

# %% [markdown]
# ### Bag of Words (BoW)

# %%
x_tr=train_df['Description']
x_test=test_df['Description']
x_cv=cv_df['Description']

# %%
bow = CountVectorizer()
x_tr_uni = bow.fit_transform(x_tr)
x_test_uni= bow.transform(x_test)
x_cv_uni= bow.transform(x_cv)

# %% [markdown]
# ### TF-IDF

# %%
tf_idf_vect = TfidfVectorizer(ngram_range=(1,2))
x_tr_tfidf = tf_idf_vect.fit_transform(x_tr)
x_test_tfidf = tf_idf_vect.transform(x_test)
x_cv_tfidf = tf_idf_vect.transform(x_cv)

# %%
def plotPrecisionRecall(y_test,y_pred):
    C = confusion_matrix(y_test, y_pred)
    A =(((C.T)/(C.sum(axis=1))).T)
    B =(C/C.sum(axis=0))
    labels = ['Art&Music','Food','History','Sci&Tech','Manu','TravelBlog']


    print("-"*20, "Precision matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(B, annot=True,annot_kws={"size": 16}, fmt='g', xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    # representing B in heatmap format
    print("-"*20, "Recall matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(A, annot=True,annot_kws={"size": 16}, fmt='g', xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Linear SVM

# %% [markdown]
# ### Unigram(BOW)

# %%
clf = SGDClassifier(loss = 'hinge', alpha = 0.01, class_weight='balanced', learning_rate='optimal',eta0=0.001, n_jobs = -1)
clf.fit(x_tr_uni,y_train)
y_pred = clf.predict(x_test_uni)
print("Accuracy on test set: %0.3f%%"%(accuracy_score(y_test, y_pred)*100))
print("Precision on test set: %0.3f"%(precision_score(y_test, y_pred,average='macro')))
print("Recall on test set: %0.3f"%(recall_score(y_test, y_pred,average='macro')))
print("F1-Score on test set: %0.3f"%(f1_score(y_test, y_pred,average='macro')))

print("-"*20, "confusion matrix", "-"*20)
plt.figure(figsize=(12,8))
matrix=confusion_matrix(y_test, y_pred)
df_cm = pd.DataFrame(matrix)
sns.set(font_scale=1.4)#for label size
labels = ['Art&Music','Food','History','Sci&Tech','Manu','TravelBlog']
sns.heatmap(df_cm, annot=True,annot_kws={"size": 16}, fmt='g',xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Class')
plt.ylabel('Original Class')
plt.show()
plotPrecisionRecall(y_test,y_pred)
# Out:
# Accuracy on test set: 91.420%
# Precision on test set: 0.914
# Recall on test set: 0.913
# F1-Score on test set: 0.913
# -------------------- confusion matrix --------------------
# -------------------- Precision matrix --------------------
# -------------------- Recall matrix --------------------

# %% [markdown]
# ### TF-IDF

# %%
clf = SGDClassifier(loss = 'hinge', alpha =0.0001, class_weight='balanced', learning_rate='optimal',eta0=0.001, n_jobs = -1)
clf.fit(x_tr_tfidf,y_train)
y_pred = clf.predict(x_test_tfidf)
print("Accuracy on test set: %0.3f%%"%(accuracy_score(y_test, y_pred)*100))
print("Precision on test set: %0.3f"%(precision_score(y_test, y_pred,average='macro')))
print("Recall on test set: %0.3f"%(recall_score(y_test, y_pred,average='macro')))
print("F1-Score on test set: %0.3f"%(f1_score(y_test, y_pred,average='macro')))

print("-"*20, "confusion matrix", "-"*20)
plt.figure(figsize=(12,8))
df_cm = pd.DataFrame(confusion_matrix(y_test, y_pred), range(6),range(6))
sns.set(font_scale=1.4)#for label size
labels = ['Art&Music','Food','History','Sci&Tech','Manu','TravelBlog']
sns.heatmap(df_cm, annot=True,annot_kws={"size": 16}, fmt='g',xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Class')
plt.ylabel('Original Class')
plt.show()
plotPrecisionRecall(y_test,y_pred)
# Out:
# Accuracy on test set: 92.498%
# Precision on test set: 0.924
# Recall on test set: 0.924
# F1-Score on test set: 0.924
# -------------------- confusion matrix --------------------
# -------------------- Precision matrix --------------------
# -------------------- Recall matrix --------------------

# %% [markdown]
# ## Bagging(Random Forest)

# %% [markdown]
# ### Splitting data into train,test

# %%
y_true = data['Category'].values
# split the data into test and train by maintaining same distribution of output varaible 'y_true' [stratify=y_true]
X_train, test_df, y_train, y_test = train_test_split(data, y_true, stratify=y_true, test_size=0.2)

# %% [markdown]
# ### BOW,TF-IDF

# %%
x_tr=X_train['Description']
x_test=test_df['Description']

# %% [markdown]
# ### BOW

# %%
bow = CountVectorizer()
x_tr_uni = bow.fit_transform(x_tr)
x_test_uni= bow.transform(x_test)

# %% [markdown]
# ### TF-IDF

# %%
tf_idf_vect = TfidfVectorizer(ngram_range=(1,2))
x_tr_tfidf = tf_idf_vect.fit_transform(x_tr)
x_test_tfidf = tf_idf_vect.transform(x_test)

# %% [markdown]
# ## BOW

# %%
RF= RandomForestClassifier(n_estimators=16,max_depth=130)
RF.fit(x_tr_uni,y_train)
y_pred =RF.predict(x_test_uni)
print("Accuracy on test set: %0.3f%%"%(accuracy_score(y_test, y_pred)*100))
print("Precision on test set: %0.3f"%(precision_score(y_test, y_pred,average='macro')))
print("Recall on test set: %0.3f"%(recall_score(y_test, y_pred,average='macro')))
print("F1-Score on test set: %0.3f"%(f1_score(y_test, y_pred,average='macro')))
print("-"*20, "confusion matrix", "-"*20)
plt.figure(figsize=(12,8))
df_cm = pd.DataFrame(confusion_matrix(y_test, y_pred), range(6),range(6))
sns.set(font_scale=1.4)#for label size
labels = ['Art&Music','Food','History','Sci&Tech','Manu','TravelBlog']
sns.heatmap(df_cm, annot=True,annot_kws={"size": 16}, fmt='g',xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Class')
plt.ylabel('Original Class')
plt.show()
plotPrecisionRecall(y_test,y_pred)
# Out:
# Accuracy on test set: 88.005%
# Precision on test set: 0.879
# Recall on test set: 0.879
# F1-Score on test set: 0.878
# -------------------- confusion matrix --------------------
# -------------------- Precision matrix --------------------
# -------------------- Recall matrix --------------------

# %% [markdown]
# ## TF-IDF

# %%
RF= RandomForestClassifier(n_estimators=20,max_depth=190)
RF.fit(x_tr_tfidf,y_train)
y_pred =RF.predict(x_test_tfidf)
print("Accuracy on test set: %0.3f%%"%(accuracy_score(y_test, y_pred)*100))
print("Precision on test set: %0.3f"%(precision_score(y_test, y_pred,average='macro')))
print("Recall on test set: %0.3f"%(recall_score(y_test, y_pred,average='macro')))
print("F1-Score on test set: %0.3f"%(f1_score(y_test, y_pred,average='macro')))
print("-"*20, "confusion matrix", "-"*20)
plt.figure(figsize=(12,8))
df_cm = pd.DataFrame(confusion_matrix(y_test, y_pred), range(6),range(6))
sns.set(font_scale=1.4)#for label size
labels = ['Art&Music','Food','History','Sci&Tech','Manu','TravelBlog']
sns.heatmap(df_cm, annot=True,annot_kws={"size": 16}, fmt='g',xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Class')
plt.ylabel('Original Class')
plt.show()

plotPrecisionRecall(y_test,y_pred)
# Out:
# Accuracy on test set: 85.445%
# Precision on test set: 0.858
# Recall on test set: 0.851
# F1-Score on test set: 0.852
# -------------------- confusion matrix --------------------
# -------------------- Precision matrix --------------------
# -------------------- Recall matrix --------------------

# %% [markdown]
# ### Saving & Loading the Model and Vectorizers

# %%
import joblib

# Saving the models
joblib.dump(clf, 'clf_model.pkl')
# Out:
# ['clf_model.pkl']

# %%
import joblib

# Saving the models
joblib.dump(RF, 'model.pkl')
# Out:
# ['model.pkl']

# %%
joblib.dump(bow, 'bow_model.pkl')
# Out:
# ['bow_model.pkl']

# %%
joblib.dump(tf_idf_vect, 'tf_idf_model.pkl')
# Out:
# ['tf_idf_model.pkl']
